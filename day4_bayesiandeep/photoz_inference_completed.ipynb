# %% [markdown]
# <a href="https://colab.research.google.com/github/EiffL/AstroHackWeek2019/blob/master/day4_ml/photoz_inference_completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2019 Francois Lanusse.
#
# Licensed under the Apache License, Version 2.0 (the "License");

# %% [markdown]
# # Estimating Photometric Redshifts with TensorFlow Probability
#
# Author: [@EiffL](https://github.com/EiffL) (Francois Lanusse)
#
# ### Overview
#
# In this tutorial, we learn how to combine Keras, TensorFlow Probability, and Google Colab to train a model photo-z inference in the cloud.
#
# We will be using data from the HSC Survey, and more specifically from the Public Data Release 2, which can be found here: https://hsc-release.mtk.nao.ac.jp/doc/
#
#
# The dataset contains postage stamps of galaxies in 5 HSC bands, along with corresponding spectroscopic redshifts.
#
# Our goal will be to estimate redshift just by looking at a picture of a galaxy.
#
# ### Learning objectives
#
# In this notebook, we will learn how to:
# *   Build a tf.data.Dataset input pipeline.
# *   Build a simple convolutional neural network with Keras.
# *   Train a model on GPUs in the cloud.
# *   (Stretch Goal) Use TensorFlow Probability to make a probabilistic model.
#
#
# ### Instructions for enabling GPU access
#
# By default, notebooks are started without acceleration. To make sure that the runtime is configured for using GPUs, go to `Runtime > Change runtime type`, and select GPU in `Hardware Accelerator`.
#
#
#
# ### Installs and Imports

# %%
import os
import re
import time
import json
import tensorflow as tf
tf.enable_eager_execution()

# %% [markdown]
# ### Checking for GPU access

# %%
#Checking for GPU access
if tf.test.gpu_device_name() != '/device:GPU:0':
  print('WARNING: GPU device not found.')
else:
  print('SUCCESS: Found GPU: {}'.format(tf.test.gpu_device_name()))
# Out:
# SUCCESS: Found GPU: /device:GPU:0

# %% [markdown]
# ## Downloading the data

# %%
# Google Cloud Storage bucket for Estimator logs and storing
# the training dataset.
bucket = 'ahw2019' # Bucket setup for this AHW2019 tutorial
print('Using bucket: {}'.format(bucket))
# Out:
# Using bucket: ahw2019

# %%
# Retrieve the catalogs
# !gsutil -m cp gs://{bucket}/hsc_photoz/cat2/catalog_*.fits .
# !gsutil -m cp gs://{bucket}/hsc_photoz/tfrecords2/* .
# Out:
# Copying gs://ahw2019/hsc_photoz/cat2/catalog_test.fits...
# Copying gs://ahw2019/hsc_photoz/cat2/catalog_train.fits...
# - [2/2 files][ 68.3 MiB/ 68.3 MiB] 100% Done
# Operation completed over 2 objects/68.3 MiB.
# Copying gs://ahw2019/hsc_photoz/tfrecords2/testing-00000-of-00001...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00004-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00000-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00005-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00001-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00002-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00006-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00003-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00007-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00008-of-00010...
# Copying gs://ahw2019/hsc_photoz/tfrecords2/training-00009-of-00010...
# - [11/11 files][ 11.8 GiB/ 11.8 GiB] 100% Done  50.6 MiB/s ETA 00:00:00
# Operation completed over 11 objects/11.8 GiB.

# %%
from astropy.table import Table
cat_train = Table.read('catalog_train.fits')
cat_test = Table.read('catalog_test.fits')

# %% [markdown]
# ## Building a tf.data.Dataset Input Pipeline
#
# The first step is to read the data from the tfrecords format on disk into a tf.data.Dataset. This TensorFlow API is the canonical way to supply data to a model during training. It is fast and optimized, and supports distributed training!

# %%
# The data is saved as a TFRecord, needs to get parsed and turned into a dataset
dset = tf.data.TFRecordDataset(['training-%05d-of-00010'%i for i in range(10)])

# %%
# To extract one example from the TFRecord, we can use the following syntax:
for i in dset.take(1):
  print(i)
# Out:
# tf.Tensor(b'\n\xcd\xa1\x05\n$\n\x18attrs/specz_redshift_err\x12\x08\x12\x06\n\x04\x17\xb7\xd18\n)\n\x1dattrs/i_sdssshape_psf_shape22\x12\x08\x12\x06\n\x04\xa1\xec\x8a=\n%\n\x19attrs/y_sdssshape_shape11\x12\x08\x12\x06\n\x04I\xb3\xe8>\n%\n\x19attrs/y_sdssshape_shape12\x12\x08\x12\x06\n\x047-\x83\xbc\n(\n\x1cattrs/i_cmodel_dev_fluxsigma\x12\x08\x12\x06\n\x04\xe1\xc7\x01C\n#\n\x17attrs/g_cmodel_dev_flux\x12\x08\x12\x06\n\x04\xce\x945F\n\'\n\x1battrs/z_cmodel_exp_magsigma\x12\x08\x12\x06\n\x04\xae]\xbb:\n%\n\x19attrs/y_sdssshape_shape22\x12\x08\x12\x06\n\x04=:\xa8>\n\'\n\x1battrs/z_cmodel_dev_magsigma\x12\x08\x12\x06\n\x04lj\xba:\n)\n\x1dattrs/r_sdssshape_psf_shape11\x12\x08\x12\x06\n\x04\xa0>\xca=\n)\n\x1dattrs/r_sdssshape_psf_shape12\x12\x08\x12\x06\n\x04\x8e\xa8\x94\xbb\n)\n\x1dattrs/r_sdssshape_psf_shape22\x12\x08\x12\x06\n\x04\x10\x8b\xb9=\n\x1e\n\x12attrs/r_cmodel_mag\x12\x08\x12\x06\n\x04\xec\xec\x9cA\n%\n\x19attrs/r_sdssshape_shape11\x12\x08\x12\x06\n\x04A9\xc7>\n%\n\x19attrs/r_sdssshape_shape12\x12\x08\x12\x06\n\x04\xf1\xc4p\xbc\n"\n\x16attrs/y_cmodel_exp_mag\x12\x08\x12\x06\n\x04l\xb9\x95A\n&\n\x1aattrs/y_extendedness_value\x12\x08\x12\x06\n\x04\x00\x00\x80?\n(\n\x1cattrs/g_cmodel_dev_fluxsigma\x12\x08\x12\x06\n\x04\x92\xad=B\n%\n\x19attrs/r_sdssshape_shape22\x12\x08\x12\x06\n\x04\x8d\r\x87>\n$\n\x18attrs/r_cmodel_fluxsigma\x12\x08\x12\x06\n\x04&\x88\x86B\n\x1e\n\x12attrs/y_cmodel_mag\x12\x08\x12\x06\n\x04\xd6/\x92A\n#\n\x17attrs/i_cmodel_exp_flux\x12\x08\x12\x06\n\x04\xf0\x9b\x89G\n\x1f\n\x13attrs/r_cmodel_flux\x12\x08\x12\x06\n\x04\x0b\x10JG\n(\n\x1cattrs/z_cmodel_exp_fluxsigma\x12\x08\x12\x06\n\x04\xe4;\x02C\n"\n\x16attrs/g_cmodel_exp_mag\x12\x08\x12\x06\n\x04\xcc{\xadA\n$\n\x18attrs/i_cmodel_fluxsigma\x12\x08\x12\x06\n\x04\xd5>\x02C\n#\n\x17attrs/y_cmodel_exp_flux\x12\x08\x12\x06\n\x04\x0c{\xe7G\n#\n\x17attrs/r_cmodel_magsigma\x12\x08\x12\x06\n\x04W\x0e\xb9:\n(\n\x1cattrs/r_localbackground_flux\x12\x08\x12\x06\n\x04\xd6\xab\xb8@\n(\n\x1cattrs/y_cmodel_exp_fluxsigma\x12\x08\x12\x06\n\x04\xceqHC\n"\n\x16attrs/r_cmodel_exp_mag\x12\x08\x12\x06\n\x04>\x84\xa0A\n#\n\x17attrs/z_cmodel_magsigma\x12\x08\x12\x06\n\x04jj\xba:\n$\n\x18attrs/z_cmodel_fluxsigma\x12\x08\x12\x06\n\x04f\x95BC\n\x17\n\x0battrs/d_mag\x12\x08\x12\x06\n\x04\x80=\x87\xbe\n"\n\x16attrs/i_cmodel_exp_mag\x12\x08\x12\x06\n\x04\xdd=\x9aA\n&\n\x1aattrs/i_extendedness_value\x12\x08\x12\x06\n\x04\x00\x00\x80?\n\x1f\n\x13attrs/i_cmodel_flux\x12\x08\x12\x06\n\x04\xb4\xb7\xcfG\n(\n\x1cattrs/z_cmodel_dev_fluxsigma\x12\x08\x12\x06\n\x04\x8f\x83BC\n\x1e\n\x12attrs/i_cmodel_mag\x12\x08\x12\x06\n\x04F\xaa\x96A\n#\n\x17attrs/r_cmodel_dev_flux\x12\x08\x12\x06\n\x04r\xe7IG\n"\n\x16attrs/z_cmodel_dev_mag\x12\x08\x12\x06\n\x04\x15\xc4\x93A\n(\n\x1cattrs/y_cmodel_dev_fluxsigma\x12\x08\x12\x06\n\x042\x8d\x95C\n)\n\x1dattrs/z_sdssshape_psf_shape11\x12\x08\x12\x06\n\x04\xad6\n>\n)\n\x1dattrs/z_sdssshape_psf_shape12\x12\x08\x12\x06\n\x04iP\x18\xbc\n&\n\x1aattrs/z_extendedness_value\x12\x08\x12\x06\n\x04\x00\x00\x80?\n#\n\x17attrs/z_cmodel_dev_flux\x12\x08\x12\x06\n\x04\xf1\x02\x11H\n\x1f\n\x13attrs/y_cmodel_flux\x12\x08\x12\x06\n\x04=\xec-H\n)\n\x1dattrs/z_sdssshape_psf_shape22\x12\x08\x12\x06\n\x04\x03l\x0f>\n\x12\n\x02id\x12\x0c\x1a\n\n\x08\xaa\xcd\x81\x80\xe0\x98\xcc{\n\'\n\x1battrs/g_cmodel_exp_magsigma\x12\x08\x12\x06\n\x04\x16\\\x92;\n\x1b\n\x0fattrs/specz_dec\x12\x08\x12\x06\n\x04Qa+B\n\'\n\x1battrs/g_cmodel_dev_magsigma\x12\x08\x12\x06\n\x04\xcf+\x91;\n)\n\x1dattrs/g_sdssshape_psf_shape11\x12\x08\x12\x06\n\x04\x9c]\x02>\n)\n\x1dattrs/g_sdssshape_psf_shape12\x12\x08\x12\x06\n\x04\x142\xc9\xba\n#\n\x17attrs/i_cmodel_magsigma\x12\x08\x12\x06\n\x04KH\xae:\n&\n\x1aattrs/r_extendedness_value\x12\x08\x12\x06\n\x04\x00\x00\x80?\n)\n\x1dattrs/g_sdssshape_psf_shape22\x12\x08\x12\x06\n\x04M>\xf2=\n%\n\x19attrs/i_sdssshape_shape11\x12\x08\x12\x06\n\x04\xff\x04\x9a>\n%\n\x19attrs/i_sdssshape_shape12\x12\x08\x12\x06\n\x04\x8f\xd4`\xbc\n%\n\x19attrs/i_sdssshape_shape22\x12\x08\x12\x06\n\ ...

# %% [markdown]
# The data is currently stored in a serialized format, as strings. We need to decode it.

# %%
img_len = 64
num_bands = 5

# This function defines the operations to apply to a serialized example to
# turn it back into a dictionary object
def parse_example(example):

  # First, let's define what fields we are expecting
  data_fields = {
      "image/encoded": tf.FixedLenFeature((), tf.string),
      "image/format": tf.FixedLenFeature((), tf.string),
      "id": tf.FixedLenFeature((), tf.int64)
  }
  for k in cat_train.colnames[5:]:
    data_fields['attrs/'+k] = tf.FixedLenFeature([], tf.float32)

  parsed_example = tf.parse_single_example(example, data_fields)

  # Decode the image from string format
  cutout = tf.decode_raw(parsed_example['image/encoded'], out_type=tf.float32) 
  cutout = tf.reshape(cutout, [img_len, img_len, num_bands])

  # Outputs results as a dictionary
  output_dict = {"cutout": cutout}
  for k in cat_train.colnames[5:]:
    output_dict[k] = parsed_example['attrs/'+k]

  return output_dict

# %% [markdown]
# With this decoding function defined, we can apply it to the dataset by using the dataset.map() method:

# %%
train_dset = dset.map(parse_example)

# %% [markdown]
# Let's have a look at the content of this new dataset:

# %%
for i in train_dset.take(1):
  print(i)
# Out:
# {'cutout': <tf.Tensor: id=384, shape=(64, 64, 5), dtype=float32, numpy=
# array([[[ 1.42860785e-02, -3.73271368e-02, -8.00432712e-02,
#           1.68011785e-01, -1.14968955e-03],
#         [ 3.54450978e-02, -7.84243457e-03,  7.13276640e-02,
#          -1.42931923e-01, -2.98915625e-01],
#         [ 5.76633587e-03,  2.51381043e-02, -2.27141455e-02,
#          -6.58935830e-02,  4.00278330e-01],
#         ...,
#         [-9.51873418e-03,  5.43134063e-02, -3.14920060e-02,
#          -2.05706120e-01,  9.59639996e-02],
#         [ 1.89720672e-02,  2.53469851e-02,  1.69368848e-01,
#           1.59295872e-01, -4.36530739e-01],
#         [-1.61630847e-02,  7.68938512e-02,  5.04950248e-02,
#           1.12778299e-01, -7.13033602e-02]],
#
#        [[-3.06963772e-02,  6.61610020e-03,  5.50234057e-02,
#          -1.87741667e-02,  2.46280819e-01],
#         [ 6.05988652e-02, -4.44212966e-02, -7.38758668e-02,
#          -2.94351697e-01, -2.96003938e-01],
#         [ 2.63932832e-02,  9.19254497e-02, -1.69459321e-02,
#           1.45460129e-01,  2.05266163e-01],
#         ...,
#         [ 3.33473980e-02,  5.73479347e-02,  4.99295667e-02,
#           9.77022126e-02,  2.04655617e-01],
#         [-1.14204688e-02,  8.01615193e-02, -3.91879305e-02,
#          -9.57644656e-02,  5.97133897e-02],
#         [ 3.69765284e-03,  8.36254731e-02,  1.06924571e-01,
#          -1.65901661e-01,  1.31112948e-01]],
#
#        [[ 4.54872064e-02, -9.62450802e-02,  6.07588403e-02,
#          -1.79299116e-01,  2.11209655e-01],
#         [-2.84522474e-02,  1.08081795e-01,  1.79444700e-02,
#          -8.01153705e-02,  4.16744798e-01],
#         [-2.63438709e-02,  8.93030763e-02,  4.51344736e-02,
#           1.50026783e-01, -3.96568596e-01],
#         ...,
#         [-1.08149257e-02,  1.07247151e-01,  7.41995946e-02,
#           1.92106262e-01,  6.32084548e-01],
#         [ 1.83662977e-02,  3.35019305e-02,  1.57419920e-01,
#           1.55436739e-01,  5.80453932e-01],
#         [-7.06411374e-04,  9.29901749e-02,  8.37437361e-02,
#           1.79383233e-01, -1.87854413e-02]],
#
#        ...,
#
#        [[-1.81376413e-02,  3.62208746e-02, -3.16679594e-04,
#           3.94323580e-02,  6.81561381e-02],
#         [-4.04464044e-02, -1.76594080e-03, -9.14404690e-02,
#          -1.58019140e-02,  3.70147794e-01],
#         [-2.02767029e-02,  7.15437829e-02, -1.70960262e-01,
#           1.05675459e-01,  6.43269122e-02],
#         ...,
#         [ 2.90678553e-02,  4.25147936e-02, -9.90848988e-02,
#           4.11051773e-02, -5.57416752e-02],
#         [-5.50357662e-02,  2.05937456e-02,  1.22239225e-01,
#          -1.62405118e-01,  6.47587702e-02],
#         [ 1.83511078e-02,  6.75156713e-02,  1.32893715e-02,
#           1.35552138e-01,  1.23430111e-01]],
#
#        [[ 3.70932110e-02, -3.32181267e-02,  1.92201987e-01,
#          -3.66747268e-02,  2.74780333e-01],
#         [ 9.36449878e-03, -1.12439990e-02,  3.80848907e-03,
#          -1.59476861e-01,  3.96629609e-02],
#         [ 2.88932049e-03,  5.26160328e-03, -8.18052441e-02,
#          -5.68646891e-03,  6.48256615e-02],
#         ...,
#         [ 6.43693358e-02,  3.06404531e-02, -4.42460999e-02,
#           2.68893372e-02, -3.12543005e-01],
#         [-2.48302482e-02, -9.92776453e-03,  1.75690174e-01,
#           1.23307094e-01, -7.23999068e-02],
#         [-2.62052771e-02, -5.21488823e-02,  3.43124270e-02,
#           4.11659896e-01,  1.67131171e-01]],
#
#        [[ 2.97912816e-03, -4.42309268e-02, -9.74009335e-02,
#          -7.43654147e-02,  5.95283136e-03],
#         [-2.38040998e-03,  3.38277034e-02,  2.32630253e-01,
#          -1.94814399e-01,  3.12707931e-01],
#         [ 4.72374633e-02, -2.08463557e-02, -3.28751542e-02,
#          -1.78562209e-01, -2.09765881e-02],
#         ...,
#         [-1.30800232e-02, -2.77226157e-02,  7.03952238e-02,
#          -1.50977314e-01, -3.22358280e-01],
#         [ 5.31086291e-04, -8.25135708e-02,  1.09458640e-01,
#          -6.62146881e-02,  5.10077477e-02],
#         [-7.22194090e-02, -2.72201598e-02, -4.23763953e-02,
#           2.75271893e-01, -5.34819141e-02]]], dtype=float32)>, 'a_g': <tf.Tensor: id=379, shape=(), dtype=float32, numpy=0.060073767>, 'a_r': <tf.Tensor: id=381, shape=(), dtype=float32, numpy=0.042199966>, 'a_i': <tf.Tensor: id=380, shape=(), dtype=float32, numpy=0.03027792>, 'a_z': <tf.Tensor: id=383, shape=(), dtype=float32, numpy=0.023417644>, 'a_y': <tf.Tensor: id=382, shape=(), dtype=float32, numpy=0.019931883>, 'g_extendedness_value': <tf.Tensor: id=399, shape=(), dtype=float32, numpy=1.0>, 'r_extendedness_value': <tf.Tensor: id=439, shape=(), dtype=float32, numpy=1.0>, 'i_extendedness_value': <tf.Tensor: id=419, shape=(), dtype=float32, numpy=1.0>, 'z_extendedness_value': <tf.Tensor: id=484, shape=(), dtype=float32, numpy=1.0>, 'y_extendedness_value': <tf.Tensor: id=464, shape=(), dtype=float32, numpy=1.0>, 'g_localbackground_flux': <tf.Tensor: id=400, shape=(), dtype=float32, numpy=1.8702477>, 'r_localbackground_flux': <tf.Tensor: id=440, shape=(), dtype=float32, numpy=5.770976>, 'i_localbackground_flux': <tf.Tensor: id=420, shape=(), dtype=float32, numpy=20.360838>, 'z_localbackground_flux': <tf.Tensor: id=485, shape=(), dtype=float32, numpy=8.610909>, 'y_localbackground_flux': <tf.Tensor: id=465, shape=(), dtype=float32, numpy=17.299044>, 'g_cmodel_flux': <tf.Tensor: id=395, shape=(), dtype=float32, numpy=11630.507>, 'g_cmodel_fluxsigma': <tf.Tensor: id=396, shape=(), dtype=float32, numpy=47.457474>, 'g_cmodel_exp_flux': <tf.Tensor: id=391, shape=(), dtype=float32, numpy=7688.1235>, 'g_cmodel_exp_fluxsigma': <tf.Tensor: id=392, shape=(), dtype=float32, numpy=31.627703>, 'g_cmodel_dev_flux': <tf.Tensor: id=387, shape=(), dtype=float32, numpy=11621.201>, 'g_cmodel_dev_fluxsigma': <tf.Tensor: id=388, shape=(), dtype=float32, numpy=47.419502>, 'r_cmodel_flux': <tf.Tensor: id=435, shape=(), dtype=float32, numpy=51728.043>, 'r_cmodel_fluxsigma': <tf.Tensor: id=436, shape=(), dtype=float32, numpy=67.265915>, 'r_cmodel_exp_flux': <tf.Tensor: id=431, shape=(), dtype=float32, numpy=34211.434>, 'r_cmodel_exp_fluxsigma': <tf.Tensor: id=432, shape=(), dtype=float32, numpy=44.62694>, 'r_cmodel_dev_flux': <tf.Tensor: id=427, shape=(), dtype=float32, numpy=51687.445>, 'r_cmodel_dev_fluxsigma': <tf.Tensor: id=428, shape=(), dtype=float32, numpy=67.21312>, 'i_cmodel_flux': <tf.Tensor: id=415, shape=(), dtype=float32, numpy=106351.41>, 'i_cmodel_fluxsigma': <tf.Tensor: id=416, shape=(), dtype=float32, numpy=130.24544>, 'i_cmodel_exp_flux': <tf.Tensor: id=411, shape=(), dtype=float32, numpy=70455.875>, 'i_cmodel_exp_fluxsigma': <tf.Tensor: id=412, shape=(), dtype=float32, numpy=86.44432>, 'i_cmodel_dev_flux': <tf.Tensor: id=407, shape=(), dtype=float32, numpy=105971.98>, 'i_cmodel_dev_fluxsigma': <tf.Tensor: id=408, shape=(), dtype=float32, numpy=129.78078>, 'z_cmodel_flux': <tf.Tensor: id=480, shape=(), dtype=float32, numpy=148544.98>, 'z_cmodel_fluxsigma': <tf.Tensor: id=481, shape=(), dtype=float32, numpy=194.58359>, 'z_cmodel_exp_flux': <tf.Tensor: id=476, shape=(), dtype=float32, numpy=98916.28>, 'z_cmodel_exp_fluxsigma': <tf.Tensor: id=477, shape=(), dtype=float32, numpy=130.23395>, 'z_cmodel_dev_flux': <tf.Tensor: id=472, shape=(), dtype=float32, numpy=148491.77>, 'z_cmodel_dev_fluxsigma': <tf.Tensor: id=473, shape=(), dtype=float32, numpy=194.5139>, 'y_cmodel_flux': <tf.Tensor: id=460, shape=(), dtype=float32, numpy=178096.95>, 'y_cmodel_fluxsigma': <tf.Tensor: id=461, shape=(), dtype=float32, numpy=299.44427>, 'y_cmodel_exp_flux': <tf.Tensor: id=456, shape=(), dtype=float32, numpy=118518.09>, 'y_cmodel_exp_fluxsigma': <tf.Tensor: id=457, shape=(), dtype=float32, numpy=200.44455>, 'y_cmodel_dev_flux': <tf.Tensor: id=452, shape=(), dtype=float32, numpy=177894.03>, 'y_cmodel_dev_fluxsigma': <tf.Tensor: id=453, shape=(), dtype=float32, numpy=299.1031>, 'g_cmodel_mag': <tf.Tensor: id=397, shape=(), dtype=float32, numpy=21.236004>, 'g_cmodel_magsigma': <tf.Tensor: id=398, shape=(), dtype=float32, numpy=0.004430271>, 'g_cmodel_exp_ma ...

# %% [markdown]
# Now our dataset is decoded into numbers and arrays.

# %% [markdown]
# ### Dataset preprocessing
#
# An important step of any input pipeline is to make
# sure the data is reasonably well behaved before
# feeding to the neural network. Here are some common strategies:
#
#
# *   Apply log() to values with large dynamic range
# *   Remove means, and standardize standard deviation
# *   etc...
#
#
# So, we begin by looking at our data

# %%
# What's in our dataset:
train_dset
# Out:
# <DatasetV1Adapter shapes: {cutout: (64, 64, 5), a_g: (), a_r: (), a_i: (), a_z: (), a_y: (), g_extendedness_value: (), r_extendedness_value: (), i_extendedness_value: (), z_extendedness_value: (), y_extendedness_value: (), g_localbackground_flux: (), r_localbackground_flux: (), i_localbackground_flux: (), z_localbackground_flux: (), y_localbackground_flux: (), g_cmodel_flux: (), g_cmodel_fluxsigma: (), g_cmodel_exp_flux: (), g_cmodel_exp_fluxsigma: (), g_cmodel_dev_flux: (), g_cmodel_dev_fluxsigma: (), r_cmodel_flux: (), r_cmodel_fluxsigma: (), r_cmodel_exp_flux: (), r_cmodel_exp_fluxsigma: (), r_cmodel_dev_flux: (), r_cmodel_dev_fluxsigma: (), i_cmodel_flux: (), i_cmodel_fluxsigma: (), i_cmodel_exp_flux: (), i_cmodel_exp_fluxsigma: (), i_cmodel_dev_flux: (), i_cmodel_dev_fluxsigma: (), z_cmodel_flux: (), z_cmodel_fluxsigma: (), z_cmodel_exp_flux: (), z_cmodel_exp_fluxsigma: (), z_cmodel_dev_flux: (), z_cmodel_dev_fluxsigma: (), y_cmodel_flux: (), y_cmodel_fluxsigma: (), y_cmodel_exp_flux: (), y_cmodel_exp_fluxsigma: (), y_cmodel_dev_flux: (), y_cmodel_dev_fluxsigma: (), g_cmodel_mag: (), g_cmodel_magsigma: (), g_cmodel_exp_mag: (), g_cmodel_exp_magsigma: (), g_cmodel_dev_mag: (), g_cmodel_dev_magsigma: (), r_cmodel_mag: (), r_cmodel_magsigma: (), r_cmodel_exp_mag: (), r_cmodel_exp_magsigma: (), r_cmodel_dev_mag: (), r_cmodel_dev_magsigma: (), i_cmodel_mag: (), i_cmodel_magsigma: (), i_cmodel_exp_mag: (), i_cmodel_exp_magsigma: (), i_cmodel_dev_mag: (), i_cmodel_dev_magsigma: (), z_cmodel_mag: (), z_cmodel_magsigma: (), z_cmodel_exp_mag: (), z_cmodel_exp_magsigma: (), z_cmodel_dev_mag: (), z_cmodel_dev_magsigma: (), y_cmodel_mag: (), y_cmodel_magsigma: (), y_cmodel_exp_mag: (), y_cmodel_exp_magsigma: (), y_cmodel_dev_mag: (), y_cmodel_dev_magsigma: (), g_sdssshape_shape11: (), g_sdssshape_shape12: (), g_sdssshape_shape22: (), g_sdssshape_psf_shape11: (), g_sdssshape_psf_shape12: (), g_sdssshape_psf_shape22: (), r_sdssshape_shape11: (), r_sdssshape_shape12: (), r_sdssshape_shape22: (), r_sdssshape_psf_shape11: (), r_sdssshape_psf_shape12: (), r_sdssshape_psf_shape22: (), i_sdssshape_shape11: (), i_sdssshape_shape12: (), i_sdssshape_shape22: (), i_sdssshape_psf_shape11: (), i_sdssshape_psf_shape12: (), i_sdssshape_psf_shape22: (), z_sdssshape_shape11: (), z_sdssshape_shape12: (), z_sdssshape_shape22: (), z_sdssshape_psf_shape11: (), z_sdssshape_psf_shape12: (), z_sdssshape_psf_shape22: (), y_sdssshape_shape11: (), y_sdssshape_shape12: (), y_sdssshape_shape22: (), y_sdssshape_psf_shape11: (), y_sdssshape_psf_shape12: (), y_sdssshape_psf_shape22: (), d_pos: (), d_mag: (), specz_ra: (), specz_dec: (), specz_redshift: (), specz_redshift_err: (), specz_mag_i: ()}, types: {cutout: tf.float32, a_g: tf.float32, a_r: tf.float32, a_i: tf.float32, a_z: tf.float32, a_y: tf.float32, g_extendedness_value: tf.float32, r_extendedness_value: tf.float32, i_extendedness_value: tf.float32, z_extendedness_value: tf.float32, y_extendedness_value: tf.float32, g_localbackground_flux: tf.float32, r_localbackground_flux: tf.float32, i_localbackground_flux: tf.float32, z_localbackground_flux: tf.float32, y_localbackground_flux: tf.float32, g_cmodel_flux: tf.float32, g_cmodel_fluxsigma: tf.float32, g_cmodel_exp_flux: tf.float32, g_cmodel_exp_fluxsigma: tf.float32, g_cmodel_dev_flux: tf.float32, g_cmodel_dev_fluxsigma: tf.float32, r_cmodel_flux: tf.float32, r_cmodel_fluxsigma: tf.float32, r_cmodel_exp_flux: tf.float32, r_cmodel_exp_fluxsigma: tf.float32, r_cmodel_dev_flux: tf.float32, r_cmodel_dev_fluxsigma: tf.float32, i_cmodel_flux: tf.float32, i_cmodel_fluxsigma: tf.float32, i_cmodel_exp_flux: tf.float32, i_cmodel_exp_fluxsigma: tf.float32, i_cmodel_dev_flux: tf.float32, i_cmodel_dev_fluxsigma: tf.float32, z_cmodel_flux: tf.float32, z_cmodel_fluxsigma: tf.float32, z_cmodel_exp_flux: tf.float32, z_cmodel_exp_fluxsigma: tf.float32, z_cmodel_dev_flux: tf.float32, z_cmodel_dev_fluxsigma: tf.float32, y_cmodel_flux: tf.float32, y_cmodel_fluxsigma: tf.float32,  ...

# %% [markdown]
# Ok, we see that this dataset is a dictionary, field `inputs` are hsc cutouts in 5 bands (g,r,i,z,y), this will be the inputs to our CNN. We also see a `specz_redshift` entry, that will be our prediction target. Let's have a look at these.

# %%
from astropy.visualization import make_lupton_rgb
# %pylab inline 

# The data is in 5 bands GRIZY, but for visualisation we use only the
# 3 first bands and luptonize them
def luptonize(img):
  return make_lupton_rgb(img[:,:,2], img[:,:,1], img[:,:,0],
                         Q=15, stretch=0.5, minimum=0)

plt.figure(figsize=(10,10))
for i, entry in enumerate(train_dset.take(25)):
  plt.subplot(5,5,i+1)
  plt.imshow(luptonize(entry['cutout']))
  plt.title('z = %0.02f'%entry['specz_redshift'])
  plt.axis('off')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# How nice is that :-) We can extract postage stamps and the corresponding spectroscopic redshift for these objects.
#
# Before doing anything else, we should take a closer look at the  data and check that it's well behaved.

# %%
# Let's collect a few examples to check their distributions
cutouts=[]
specz = []
for (batch, entry) in enumerate(train_dset.take(1000)):
  specz.append(entry['specz_redshift'])
  cutouts.append(entry['cutout'])

cutouts = np.stack(cutouts)
specz = np.stack(specz)

# %%
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.hist(cutouts[...,i].flatten(),100, label=b);
plt.legend()

# Problem ?

# %%
plt.figure(figsize=(15,3))
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.subplot(1,5,i+1)
  plt.imshow(cutouts[0,:,:,i],vmin=-1,vmax=50)
  plt.title(b)
  plt.axis('off')

plt.figure(figsize=(15,3))
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.subplot(1,5,i+1)
  plt.imshow(cutouts[1,:,:,i],vmin=-1,vmax=50)
  plt.title(b)
  plt.axis('off')

# %%
# Let's look at it in log scale
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.hist(cutouts[...,i].flatten(),100, label=b,alpha=0.5);
plt.legend()
plt.yscale('log')

# %% [markdown]
# This is terrible, the tail of this distribution in pixel intensity is going to kill our neural networks. We need to standardize the data.

# %%
# Let's evaluate the noise standard deviation in each band, and apply range 
# compression accordingly
from astropy.stats import mad_std
scaling = []

for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.hist(cutouts[...,i].flatten(),100, label=b,alpha=0.5,range=[-1,1]);
  sigma = mad_std(cutouts[...,i].flatten())
  scaling.append(sigma)
  plt.axvline(sigma, color='C%d'%i,alpha=0.5)
  plt.axvline(-sigma, color='C%d'%i,alpha=0.5)
plt.legend()

# %%
# Let's have a look at this distribution if we rescale each band by the standard
# deviation
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.hist(cutouts[...,i].flatten()/scaling[i],100, label=b,alpha=0.5,
           range=[-10,10]);
legend()

# %% [markdown]
# Sweet! Now there is still an unsigthly tail towards very large values. We are going to apply range compression to get rid of it.

# %%
# a common approach for range compression is to apply arcsinh to suppress the
# high amplitude values
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.hist(np.arcsinh(cutouts[...,i].flatten()/scaling[i]/3),100,
           label=b, alpha=0.5);
plt.legend()
plt.yscale('log')

# %% [markdown]
# ![Perfection](https://i.kym-cdn.com/entries/icons/original/000/022/900/704.jpg)

# %%
# we can have a look at individual postage stamps with or without this scaling
subplot(121)
imshow(cutouts[0,:,:,i]/scaling[i])
title('Before')
subplot(122)
imshow(np.arcsinh(cutouts[0,:,:,1]/scaling[1]/3))
title('After');

# %%
# Let's just check the specz values
plt.hist(specz,100);
# Should be ok

# %% [markdown]
# Now that we have defined a scaling for the data that should be appropriate, we can build a scaling function and apply it to the dataset:

# %%
# Using a mapping function to apply preprocessing to our data
def preprocessing(example):
  def range_compression(img):
    return tf.math.asinh(img / tf.constant(scaling) / 3. )
  # Our preprocessing function only returns the postage stamps, and the specz
  return range_compression(example['cutout']), example['specz_redshift']

# %%
dset = train_dset.map(preprocessing)

# %%
# Let's draw some examples from this  now
cutouts=[]
specz = []
for (batch, entry) in enumerate(dset.take(1000)):
  specz.append(entry[1])
  cutouts.append(entry[0])

cutouts = np.stack(cutouts)
specz = np.stack(specz)

# %%
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.hist(cutouts[...,i].flatten(),100, label=b,alpha=0.5, range=[-1,6]);
plt.legend()

# %%
plt.figure(figsize=(15,3))
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.subplot(1,5,i+1)
  plt.imshow(cutouts[0,:,:,i],vmin=-1,vmax=6)
  plt.title(b)
  plt.axis('off')

plt.figure(figsize=(15,3))
for i,b in enumerate(['g', 'r', 'i', 'z', 'y']):
  plt.subplot(1,5,i+1)
  plt.imshow(cutouts[1,:,:,i],vmin=-1,vmax=6)
  plt.title(b)
  plt.axis('off')

# %% [markdown]
# Sweeeeeet

# %% [markdown]
# ### Create the input pipeline
#
# Now that we know how to preprocess the data, we can build the input pipeline. Below is a function that creates a Dataset object from the tfrecords files, decode them, applies preprocessing, shuffles the dataset, and create batches of data. Finally the function returns the dataset, that Keras models can directly ingest.
#
# More information about tf.data.dataset API can be found here:
#
# https://www.tensorflow.org/guide/datasets

# %%
# Using a mapping function to apply preprocessing to our data
def preprocessing(example):
  img = tf.math.asinh(example['cutout'] / tf.constant(scaling) / 3. )
  return img, example['specz_redshift']

def input_fn(mode, batch_size):
  """
  mode: tf.estimator.ModeKeys.TRAIN or tf.estimator.ModeKeys.EVAL
  """
  if mode == tf.estimator.ModeKeys.TRAIN:
    dataset = tf.data.Dataset.list_files('training-*')
    dataset = dataset.interleave(tf.data.TFRecordDataset, 
                                 cycle_length=10,
                                 num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.repeat()
  else:
    dataset = tf.data.TFRecordDataset('testing-00000-of-00001')
    
  dataset = dataset.map(parse_example)
  if mode == tf.estimator.ModeKeys.TRAIN:
    dataset = dataset.shuffle(10000)
  dataset = dataset.batch(batch_size, drop_remainder=True)
  dataset = dataset.map(preprocessing) # Apply data preprocessing
  dataset = dataset.prefetch(-1) # fetch next batches while training current one (-1 for autotune)
  return dataset

# %% [markdown]
# ## Building a simple regression model with Keras

# %%
import tensorflow.keras as tfk

def create_model():
  model = tfk.models.Sequential()
  model.add(tfk.layers.Conv2D(32, kernel_size=5, padding='same',
                                   input_shape=(64,64,5), activation='elu', strides=2))
  model.add(tfk.layers.BatchNormalization())
  
  model.add(tfk.layers.Conv2D(64, kernel_size=3, padding='same', 
                              activation='elu'))
  model.add(tfk.layers.BatchNormalization())
  
  model.add(tfk.layers.Conv2D(128, kernel_size=3, padding='same', strides=2, 
                                   activation='elu'))
  model.add(tfk.layers.BatchNormalization())  

  model.add(tfk.layers.Conv2D(256, kernel_size=3, padding='same', 
                                   activation='elu', strides=2))
  model.add(tfk.layers.BatchNormalization())

  model.add(tfk.layers.Conv2D(512, kernel_size=3, padding='same', 
                                   activation='elu', strides=2))
  model.add(tfk.layers.BatchNormalization())
  
  model.add(tfk.layers.Flatten())
  model.add(tfk.layers.Dense(512))
  model.add(tfk.layers.Activation('relu'))
  model.add(tfk.layers.Dense(256))
  model.add(tfk.layers.Activation('relu'))
  model.add(tfk.layers.Dense(1))
  
  model.compile(optimizer='adam', # learning rate will be set by LearningRateScheduler
                loss=tfk.metrics.mse)
  return model

# %%
model = create_model()

# print model layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        4032
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 5,902,081
# Trainable params: 5,900,097
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
# We define the batch size
BATCH_SIZE = 64

# Learning rate schedule
LEARNING_RATE=0.001
LEARNING_RATE_EXP_DECAY=0.9

lr_decay = tfk.callbacks.LearningRateScheduler(
    lambda epoch: LEARNING_RATE * LEARNING_RATE_EXP_DECAY**epoch,
    verbose=True)

# %%
# We actually create our training dataset with our input function
dataset_training = input_fn(tf.estimator.ModeKeys.TRAIN, BATCH_SIZE)

# %%
# We are ready to train our model
model.fit(dataset_training,
          steps_per_epoch=20000//BATCH_SIZE, 
          epochs=15,
          callbacks=[lr_decay])
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/15
# 312/312 [==============================] - 40s 128ms/step - loss: 1.0490
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009000000000000001.
# Epoch 2/15
# 312/312 [==============================] - 31s 98ms/step - loss: 0.0604
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0008100000000000001.
# Epoch 3/15
# 312/312 [==============================] - 31s 99ms/step - loss: 0.0559
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0007290000000000002.
# Epoch 4/15
# 312/312 [==============================] - 31s 99ms/step - loss: 0.0487
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0006561000000000001.
# Epoch 5/15
# 312/312 [==============================] - 31s 100ms/step - loss: 0.0449
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.00059049.
# Epoch 6/15
# 312/312 [==============================] - 31s 99ms/step - loss: 0.0568
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000531441.
# Epoch 7/15
# 312/312 [==============================] - 31s 99ms/step - loss: 0.0411
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0004782969000000001.
# Epoch 8/15
# 312/312 [==============================] - 30s 97ms/step - loss: 0.0406
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0004304672100000001.
# Epoch 9/15
# 312/312 [==============================] - 30s 96ms/step - loss: 0.0398
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003874204890000001.
# Epoch 10/15
# 312/312 [==============================] - 31s 100ms/step - loss: 0.0346
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003486784401000001.
# Epoch 11/15
# 312/312 [==============================] - 31s 99ms/step - loss: 0.0385
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003138105960900001.
# Epoch 12/15
# 312/312 [==============================] - 31s 98ms/step - loss: 0.0372
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002824295364810001.
# Epoch 13/15
# 312/312 [==============================] - 30s 97ms/step - loss: 0.0378
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002541865828329001.
# Epoch 14/15
# 312/312 [==============================] - 30s 97ms/step - loss: 0.0386
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0002287679245496101.
# Epoch 15/15
# 312/312 [==============================] - 31s 98ms/step - loss: 0.0307

# %%
# Now that the model is 'trained', we can apply it
dataset_eval = input_fn(tf.estimator.ModeKeys.EVAL, BATCH_SIZE)
preds = model.predict(dataset_eval)

# %%
# %pylab inline
hist2d(cat_test['specz_redshift'][:20000], preds.squeeze()[:20000], 64,
       range=[[0,1],[0,1]], cmap='gist_stern'); 
gca().set_aspect('equal');
plot([0,1],[0,1],color='r')
xlabel('Spectroscopic Redshift')
ylabel('Predicted Redshift')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0, 0.5, 'Predicted Redshift')

# %% [markdown]
# Yes! It's learning something! But the results may not be perfect yet. Here  is a list of things to do to improve the model:
# *   Train for longer ^^' Deep Learning requires a lot of patience
# *   Include additional information, like the extinction in each band, which is included in the dataset.
#     *   You would need to change the input_fn so that the returned dataset contains additional fields
#     *   See how to use multiple inputs in a Keras model here: https://keras.io/getting-started/functional-api-guide/
# *   Use a better CNN model. A simple CNN like this one is typically very suboptimal. Much better results would be achieved with a ResNet model for instance, see here for a Keras example: https://keras.io/examples/cifar10_resnet/
# *   Move away from an MSE loss and embrace TensorflowProbability \o/ Replacing the output of the model by a Mixture Density would be a much better idea. https://www.tensorflow.org/probability/api_docs/python/tfp/layers/MixtureNormal
